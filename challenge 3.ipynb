# %%
import pandas as pd
df = pd.read_csv("CC GENERAL.csv")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.drop('CUST_ID', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df.dropna(inplace = True)
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 4   817.714335           1.000000      16.00             16.00
# 5  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
# Standardize data
scaler = StandardScaler() 
x = scaler.fit_transform(df) 

#cek udah normal belum
np.mean(x),np.std(x)
# Out:
# (-8.905257293672073e-18, 1.0)

# %%
# Converting the numpy array into a pandas DataFrame 
normalized_df = pd.DataFrame(x) 
  
# Reducing the dimensions of the data 
pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(normalized_df) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2'] 
  
X_principal.head(2)
# Out:
#          P1        P2
# 0 -1.696399 -1.122589
# 1 -1.215690  2.435620

# %%
silhouette_scores = [] 

for n_cluster in range(2, 8):
    silhouette_scores.append( 
        silhouette_score(X_principal, KMeans(n_clusters = n_cluster).fit_predict(X_principal))) 
    
# Plotting a bar graph to compare the results 
k = [2, 3, 4, 5, 6,7] 
plt.bar(k, silhouette_scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
km = kmeans.fit(X_principal)

# %%
# Visualizing the clustering 
plt.scatter(X_principal['P1'], X_principal['P2'],  
           c = KMeans(n_clusters = 2).fit_predict(X_principal), cmap =plt.cm.winter) 
plt.show()

# %%
c = KMeans(n_clusters = 2).fit_predict(X_principal)
df['cluster'] = c

# %%
df.head(20)
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     40.900749           0.818182      95.40              0.00
# 1   3202.467416           0.909091       0.00              0.00
# 2   2495.148862           1.000000     773.17            773.17
# 4    817.714335           1.000000      16.00             16.00
# 5   1809.828751           1.000000    1333.28              0.00
# 6    627.260806           1.000000    7091.01           6402.63
# 7   1823.652743           1.000000     436.20              0.00
# 8   1014.926473           1.000000     861.49            661.49
# 9    152.225975           0.545455    1281.60           1281.60
# 10  1293.124939           1.000000     920.12              0.00
# 11   630.794744           0.818182    1492.18           1492.18
# 12  1516.928620           1.000000    3217.99           2500.23
# 13   921.693369           1.000000    2137.93            419.96
# 14  2772.772734           1.000000       0.00              0.00
# ...

# %%
cluster0 = df[df['cluster']==0]
cluster1 = df[df['cluster']==1]

# %%
cluster0[cluster0.columns[cluster0.columns!='cluster'] ].mean()
# Out:
# BALANCE                             2390.817881
# BALANCE_FREQUENCY                      0.979352
# PURCHASES                           3824.791976
# ONEOFF_PURCHASES                    2366.993913
# INSTALLMENTS_PURCHASES              1458.207813
# CASH_ADVANCE                         899.974769
# PURCHASES_FREQUENCY                    0.939095
# ONEOFF_PURCHASES_FREQUENCY             0.598920
# PURCHASES_INSTALLMENTS_FREQUENCY       0.751213
# CASH_ADVANCE_FREQUENCY                 0.088764
# CASH_ADVANCE_TRX                       2.499341
# PURCHASES_TRX                         51.197628
# CREDIT_LIMIT                        7628.557312
# PAYMENTS                            4181.434259
# MINIMUM_PAYMENTS                    1357.449346
# PRC_FULL_PAYMENT                       0.285000
# TENURE                                11.901845
# dtype: float64

# %%
cluster1[cluster1.columns[cluster1.columns != 'cluster']].mean()
# Out:
# BALANCE                             1432.834593
# BALANCE_FREQUENCY                      0.877053
# PURCHASES                            428.436741
# ONEOFF_PURCHASES                     229.113804
# INSTALLMENTS_PURCHASES               199.612994
# CASH_ADVANCE                        1014.264979
# PURCHASES_FREQUENCY                    0.401505
# ONEOFF_PURCHASES_FREQUENCY             0.122094
# PURCHASES_INSTALLMENTS_FREQUENCY       0.287271
# CASH_ADVANCE_FREQUENCY                 0.148020
# CASH_ADVANCE_TRX                       3.487637
# PURCHASES_TRX                          7.320736
# CREDIT_LIMIT                        3859.599344
# PAYMENTS                            1273.298070
# MINIMUM_PAYMENTS                     759.135906
# PRC_FULL_PAYMENT                       0.132497
# TENURE                                11.456027
# dtype: float64
