# %%
import pandas as pd
df = pd.read_csv("train_users_2.csv")
df.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
for col in df.columns:
    print(col)
# Out:
# id
# date_account_created
# timestamp_first_active
# date_first_booking
# gender
# age
# signup_method
# signup_flow
# language
# affiliate_channel
# affiliate_provider
# first_affiliate_tracked
# signup_app
# first_device_type
# first_browser
# country_destination

# %%
for i in df.columns:
    print("jml null di",i,"adalah",len(df[df[i].isnull()]))
# Out:
# jml null di id adalah 0
# jml null di date_account_created adalah 0
# jml null di timestamp_first_active adalah 0
# jml null di date_first_booking adalah 124543
# jml null di gender adalah 0
# jml null di age adalah 87990
# jml null di signup_method adalah 0
# jml null di signup_flow adalah 0
# jml null di language adalah 0
# jml null di affiliate_channel adalah 0
# jml null di affiliate_provider adalah 0
# jml null di first_affiliate_tracked adalah 6065
# jml null di signup_app adalah 0
# jml null di first_device_type adalah 0
# jml null di first_browser adalah 0
# jml null di country_destination adalah 0

# %%
for i in df.columns:
    print("Rangkuman statistik di",i,":","\n",df[i].describe(),"\n")
# Out:
# Rangkuman statistik di id :
#  count         213451
# unique        213451
# top       wy4lt9qyf6
# freq               1
# Name: id, dtype: object
#
# Rangkuman statistik di date_account_created :
#  count         213451
# unique          1634
# top       2014-05-13
# freq             674
# Name: date_account_created, dtype: object
#
# Rangkuman statistik di timestamp_first_active :
#  count    2.134510e+05
# mean     2.013085e+13
# std      9.253717e+09
# min      2.009032e+13
# 25%      2.012123e+13
# 50%      2.013091e+13
# 75%      2.014031e+13
# max      2.014063e+13
# Name: timestamp_first_active, dtype: float64
#
# Rangkuman statistik di date_first_booking :
#  count          88908
# unique          1976
# top       2014-05-22
# freq             248
# Name: date_first_booking, dtype: object
#
# Rangkuman statistik di gender :
#  count        213451
# unique            4
# top       -unknown-
# freq          95688
# Name: gender, dtype: object
#
# Rangkuman statistik di age :
# ...
